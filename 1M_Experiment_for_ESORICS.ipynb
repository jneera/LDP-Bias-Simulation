# %%
import pandas as pd

datadf = pd.read_csv('ratings.dat',
                    sep='::',
                    header=None,
                    names=['user_id', 'item_id', 'rating', 'timestamp'],
                    engine='python')

# drop timestamp
datadf = datadf[['user_id', 'item_id', 'rating']]
print(datadf.head())
# Out:
#    user_id  item_id  rating
# 0        1     1193       5
# 1        1      661       3
# 2        1      914       3
# 3        1     3408       4
# 4        1     2355       5

# %%
def laplace_mechanism(matrix, epsilon, mean_rating):
    sensitivity = 4.0
    noise = np.random.laplace(0, sensitivity/epsilon, matrix.shape)
    noisy_matrix = matrix + noise
    noisy_matrix = np.clip(noisy_matrix, 1, 5)
    return noisy_matrix

# %%
import numpy as np

def piecewise_mechanism(x, epsilon):
    # Step 1: normalise x from [1,5] to [-1,1]
    x_norm = 2 * (x - 1) / (5 - 1) - 1
    # C = (e^(ε/2) + 1) / (e^(ε/2) - 1)
    c= (np.exp(epsilon/2)+1)/(np.exp(epsilon/2)-1)
    # p = (e^ε - e^(ε/2)) / (2 * e^(ε/2) + 2)
    p= (np.exp(epsilon)-np.exp(epsilon/2))/(2*np.exp(epsilon/2)+2)
    # l(x) = (C+1)/2 * x_norm - (C-1)/2
    # r(x) = l(x) + C - 1
    l= (c+1)/2*x_norm-(c-1)/2
    r=l+c-1
    # threshold = e^(ε/2) / (e^(ε/2) + 1)
    threshold = np.exp(epsilon/2)/(np.exp(epsilon/2)+1)
    if np.random.uniform(0, 1) < threshold:
    # heads — sample from centre zone
      output = np.random.uniform(l, r)
    else:
    # tails — sample from tails
    # left tail runs from -C to l
    # right tail runs from r to +C
    # pick one randomly
      output = np.random.uniform(-c, l) if np.random.uniform(0,1) < 0.5 else np.random.uniform(r, c)
    x_out = (output + 1) * 2 + 1
    x_out = np.clip(x_out, 1, 5)
    return x_out

# %%
def apply_piecewise(matrix, epsilon, mean_rating):
    noisy_matrix = matrix.copy()
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            if matrix[i, j] != mean_rating:
                noisy_matrix[i, j] = piecewise_mechanism(matrix[i, j], epsilon)
    return noisy_matrix

# %%
def ndcg_at_k(test, predicted_matrix, train_matrix, k=10, mean_rating=0):
    ndcg_scores = []

    # group test ratings by user
    test_grouped = test.groupby('user_id')

    for user_id, user_test in test_grouped:
        if user_id not in train_matrix.index:
            continue

        user_idx = train_matrix.index.get_loc(user_id)

        # get predicted scores for all items in test set for this user
        actual_ratings = []
        predicted_scores = []

        for _, row in user_test.iterrows():
            item_id = row['item_id']
            actual = row['rating']

            if item_id in train_matrix.columns:
                item_idx = train_matrix.columns.get_loc(item_id)
                predicted = predicted_matrix[user_idx, item_idx]
            else:
                predicted = mean_rating

            actual_ratings.append(actual)
            predicted_scores.append(predicted)

        if len(actual_ratings) < 2:
            continue

        # sort by predicted score to get top K
        paired = sorted(zip(predicted_scores, actual_ratings),
                       reverse=True)[:k]

        # compute DCG
        dcg = sum(rating / np.log2(rank + 2)
                 for rank, (_, rating) in enumerate(paired))

        # compute ideal DCG
        ideal_paired = sorted(actual_ratings, reverse=True)[:k]
        idcg = sum(rating / np.log2(rank + 2)
                  for rank, rating in enumerate(ideal_paired))

        if idcg > 0:
            ndcg_scores.append(dcg / idcg)

    return np.mean(ndcg_scores) if ndcg_scores else 0.0

# %%
def gaussian_mechanism(matrix, epsilon, delta, mean_rating):
    sensitivity = 4.0
    sigma = sensitivity * np.sqrt(2 * np.log(1.25 / delta)) / epsilon
    noise = np.random.normal(0, sigma, matrix.shape)
    noisy_matrix = matrix + noise
    noisy_matrix = np.clip(noisy_matrix, 1, 5)
    return noisy_matrix

# %%
def bounded_laplace_mechanism(matrix, epsilon, mean_rating):
    sensitivity = 1.0  # normalised scale [0,1]
    b = sensitivity / epsilon
    noisy_matrix = matrix.copy()
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            if matrix[i, j] != mean_rating:
                r = (matrix[i, j] - 1) / 4  # normalise to [0,1]
                while True:
                    noise = np.random.laplace(0, b)
                    r_noisy = r + noise
                    if 0 <= r_noisy <= 1:
                        break
                noisy_matrix[i, j] = r_noisy * 4 + 1  # denormalise
    return noisy_matrix

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import mean_squared_error

n_splits = 10
# datadf_50 = datadf.sample(frac=0.5, random_state=42)
datadf_20 = datadf.sample(frac=0.2, random_state=42)
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
for fold, (train_idx, test_idx) in enumerate(kf.split(datadf_20)):
    train = datadf_20.iloc[train_idx]
    test = datadf_20.iloc[test_idx]
all_results = []
epsilons = [0.1, 0.5, 1.0, 2.0, 5.0, 10.0]
sparsity_results = []

for fold, (train_idx, test_idx) in enumerate(kf.split(datadf_20)):
    print(f"Fold {fold+1}/{n_splits}")

    # split data
    train = datadf_20.iloc[train_idx]
    test = datadf_20.iloc[test_idx]
    print(f"Train size: {len(train)}, Test size: {len(test)}")

    try:
        train_matrix = train.pivot(index='user_id',
                                   columns='item_id',
                                   values='rating')
        print(f"Train matrix shape: {train_matrix.shape}")
    except Exception as e:
        print(f"Error building pivot at fold {fold}: {e}")
        continue
    # build matrix
    #train_matrix = train.pivot(index='user_id',
    #                           columns='item_id',
    #                           values='rating')
    train_array = train_matrix.values.astype(float)
    mean_rating = np.nanmean(train_array)
    print(f"Mean rating: {mean_rating:.4f}, NaN count: {np.isnan(train_array).sum()}")
    train_array[np.isnan(train_array)] = mean_rating
    print(f"NaN after fill: {np.isnan(train_array).sum()}")

    test_users = test['user_id'].values
    test_items = test['item_id'].values
    test_ratings = test['rating'].values
    gaussian_with_delta = lambda matrix, eps, mean_rating: gaussian_mechanism(matrix, eps, 1e-5, mean_rating)
    for eps in epsilons:
      for mechanism_name, mechanism_fn in [
        ('clipped_laplace', laplace_mechanism),
        ('bounded_laplace', bounded_laplace_mechanism),
        ('gaussian', gaussian_with_delta),
        ('piecewise', apply_piecewise)
      ]:
        try:
            noisy = mechanism_fn(train_array, eps, mean_rating)
            noisy = np.nan_to_num(noisy, nan=mean_rating,
                                  posinf=5.0, neginf=1.0)

            svd = TruncatedSVD(n_components=20, random_state=42)
            reduced = svd.fit_transform(noisy)
            predicted_matrix = np.dot(reduced, svd.components_)
            predicted_matrix = np.nan_to_num(predicted_matrix,
                                             nan=mean_rating)

            predicted_ratings = []
            for user, item in zip(test_users, test_items):
                if user in train_matrix.index and item in train_matrix.columns:
                    u_idx = train_matrix.index.get_loc(user)
                    i_idx = train_matrix.columns.get_loc(item)
                    predicted_ratings.append(predicted_matrix[u_idx, i_idx])
                else:
                    predicted_ratings.append(mean_rating)

            predicted_ratings = np.array(predicted_ratings)
            predicted_ratings = np.nan_to_num(predicted_ratings,
                                              nan=mean_rating)
            rmse = np.sqrt(mean_squared_error(test_ratings,
                                              predicted_ratings))
            ndcg = ndcg_at_k(test, predicted_matrix, train_matrix, k=10,
                  mean_rating=mean_rating)

            all_results.append({
              'fold': fold,
              'epsilon': eps,
              'mechanism': mechanism_name,
              'rmse': rmse,
              'ndcg': ndcg
            })

            print(f"Fold {fold+1}, {mechanism_name}, ε={eps}: RMSE={rmse:.4f}, NDCG@10={ndcg:.4f}")

        except Exception as e:
            print(f"ERROR at fold {fold+1}, {mechanism_name}, ε={eps}: {e}")
            continue

# compute mean and std across folds
results_df = pd.DataFrame(all_results)
summary = results_df.groupby(['epsilon', 'mechanism']).agg(
    rmse_mean=('rmse', 'mean'),
    rmse_std=('rmse', 'std'),
    ndcg_mean=('ndcg', 'mean'),
    ndcg_std=('ndcg', 'std')
).reset_index()
print(summary)
# Out:
# Fold 1/10
# Train size: 180037, Test size: 20005
# Train matrix shape: (6037, 3419)
# Mean rating: 3.5820, NaN count: 20460466
# NaN after fill: 0
# Fold 1, clipped_laplace, ε=0.1: RMSE=1.2771, NDCG@10=0.9298
# Fold 1, bounded_laplace, ε=0.1: RMSE=1.1247, NDCG@10=0.9284
# Fold 1, gaussian, ε=0.1: RMSE=1.2865, NDCG@10=0.9315
# Fold 1, piecewise, ε=0.1: RMSE=1.1202, NDCG@10=0.9373
# Fold 1, clipped_laplace, ε=0.5: RMSE=1.2305, NDCG@10=0.9319
# Fold 1, bounded_laplace, ε=0.5: RMSE=1.1233, NDCG@10=0.9299
# Fold 1, gaussian, ε=0.5: RMSE=1.2774, NDCG@10=0.9316
# Fold 1, piecewise, ε=0.5: RMSE=1.1191, NDCG@10=0.9371
# Fold 1, clipped_laplace, ε=1.0: RMSE=1.1920, NDCG@10=0.9318
# Fold 1, bounded_laplace, ε=1.0: RMSE=1.1205, NDCG@10=0.9325
# Fold 1, gaussian, ε=1.0: RMSE=1.2668, NDCG@10=0.9307
# Fold 1, piecewise, ε=1.0: RMSE=1.1147, NDCG@10=0.9390
# Fold 1, clipped_laplace, ε=2.0: RMSE=1.1525, NDCG@10=0.9329
# Fold 1, bounded_laplace, ε=2.0: RMSE=1.1185, NDCG@10=0.9353
# Fold 1, gaussian, ε=2.0: RMSE=1.2474, NDCG@10=0.9294
# Fold 1, piecewise, ε=2.0: RMSE=1.1088, NDCG@10=0.9452
# Fold 1, clipped_laplace, ε=5.0: RMSE=1.1206, NDCG@10=0.9340
# Fold 1, bounded_laplace, ε=5.0: RMSE=1.1125, NDCG@10=0.9406
# Fold 1, gaussian, ε=5.0: RMSE=1.1917, NDCG@10=0.9312
# Fold 1, piecewise, ε=5.0: RMSE=1.1027, NDCG@10=0.9496
# Fold 1, clipped_laplace, ε=10.0: RMSE=1.1146, NDCG@10=0.9379
# Fold 1, bounded_laplace, ε=10.0: RMSE=1.1061, NDCG@10=0.9484
# Fold 1, gaussian, ε=10.0: RMSE=1.1444, NDCG@10=0.9326
# Fold 1, piecewise, ε=10.0: RMSE=1.1018, NDCG@10=0.9519
# Fold 2/10
# Train size: 180037, Test size: 20005
# Train matrix shape: (6034, 3429)
# Mean rating: 3.5825, NaN count: 20510549
# NaN after fill: 0
# Fold 2, clipped_laplace, ε=0.1: RMSE=1.2722, NDCG@10=0.9316
# Fold 2, bounded_laplace, ε=0.1: RMSE=1.1218, NDCG@10=0.9294
# Fold 2, gaussian, ε=0.1: RMSE=1.2823, NDCG@10=0.9316
# Fold 2, piecewise, ε=0.1: RMSE=1.1200, NDCG@10=0.9351
# Fold 2, clipped_laplace, ε=0.5: RMSE=1.2252, NDCG@10=0.9303
# Fold 2, bounded_laplace, ε=0.5: RMSE=1.1211, NDCG@10=0.9291
# Fold 2, gaussian, ε=0.5: RMSE=1.2755, NDCG@10=0.9308
# Fold 2, piecewise, ε=0.5: RMSE=1.1159, NDCG@10=0.9383
# Fold 2, clipped_laplace, ε=1.0: RMSE=1.1900, NDCG@10=0.9308
# Fold 2, bounded_laplace, ε=1.0: RMSE=1.1186, NDCG@10=0.9321
# Fold 2, gaussian, ε=1.0: RMSE=1.2611, NDCG@10=0.9316
# Fold 2, piecewise, ε=1.0: RMSE=1.1119, NDCG@10=0.9412
# Fold 2, clipped_laplace, ε=2.0: RMSE=1.1507, NDCG@10=0.9321
# Fold 2, bounded_laplace, ε=2.0: RMSE=1.1167, NDCG@10=0.9350
# Fold 2, gaussian, ε=2.0: RMSE=1.2403, NDCG@10=0.9304
# Fold 2, piecewise, ε=2.0: RMSE=1.1076, NDCG@10=0.9446
# Fold 2, clipped_laplace, ε=5.0: RMSE=1.1192, NDCG@10=0.9339
# Fold 2, bounded_laplace, ε=5.0: RMSE=1.1099, NDCG@10=0.9418
# Fold 2, gaussian, ε=5.0: RMSE=1.1880, NDCG@10=0.9322
# Fold 2, piecewise, ε=5.0: RMSE=1.1009, NDCG@10=0.9499
# Fold 2, clipped_laplace, ε=10.0: RMSE=1.1126, NDCG@10=0.9361
# Fold 2, bounded_laplace, ε=10.0: RMSE=1.1039, NDCG@10=0.9482
# Fold 2, gaussian, ε=10.0: RMSE=1.1416, NDCG@10=0.9316
# Fold 2, piecewise, ε=10.0: RMSE=1.0999, NDCG@10=0.9522
# Fold 3/10
# Train size: 180038, Test size: 20004
# Train matrix shape: (6037, 3422)
# Mean rating: 3.5819, NaN count: 20478576
# NaN after fill: 0
# Fold 3, clipped_laplace, ε=0.1: RMSE=1.2701, NDCG@10=0.9296
# Fold 3, bounded_laplace, ε=0.1: RMSE=1.1174, NDCG@10=0.9296
# Fold 3, gaussian, ε=0.1: RMSE=1.2814, NDCG@10=0.9316
# Fold 3, piecewise, ε=0.1: RMSE=1.1136, NDCG@10=0.9352
# Fold 3, clipped_laplace, ε=0.5: RMSE=1.2229, NDCG@10=0.9316
# Fold 3, bounded_laplace, ε=0.5: RMSE=1.1150, NDCG@10=0.9298
# Fold 3, gaussian, ε=0.5: RMSE=1.2703, NDCG@10=0.9325
# Fold 3, piecewise, ε=0.5: RMSE=1.1106, NDCG@10=0.9383
# Fold 3, clipped_laplace, ε=1.0: RMSE=1.1873, NDCG@10=0.9320
# Fold 3, bounded_laplace, ε=1.0: RMSE=1.1133, NDCG@10=0.9323
# Fold 3, gaussian, ε=1.0: RMSE=1.2571, NDCG@10=0.9316
# Fold 3, piecewise, ε=1.0: RMSE=1.1073, NDCG@10=0.9401
# Fold 3, clipped_laplace, ε=2.0: RMSE=1.1438, NDCG@10=0.9318
# Fold 3, bounded_laplace, ε=2.0: RMSE=1.1103, NDCG@10=0.9349
# Fold 3, gaussian, ε=2.0: RMSE=1.2408, NDCG@10=0.9308
# Fold 3, piecewise, ε=2.0: RMSE=1.1010, NDCG@10=0.9442
# Fold 3, clipped_laplace, ε=5.0: RMSE=1.1123, NDCG@10=0.9347
# Fold 3, bounded_laplace, ε=5.0: RMSE=1.1042, NDCG@10=0.9423
# Fold 3, gaussian, ε=5.0: RMSE=1.1867, NDCG@10=0.9305
# Fold 3, piecewise, ε=5.0: RMSE=1.0950, NDCG@10=0.9506
# Fold 3, clipped_laplace, ε=10.0: RMSE=1.1076, NDCG@10=0.9356
# Fold 3, bounded_laplace, ε=10.0: RMSE=1.0980, NDCG@10=0.9482
# Fold 3, gaussian, ε=10.0: RMSE=1.1355, NDCG@10=0.9334
# Fold 3, piecewise, ε=10.0: RMSE=1.0943, NDCG@10=0.9518
# Fold 4/10
# Train size: 180038, Test size: 20004
# Train matrix shape: (6033, 3427)
# Mean rating: 3.5832, NaN count: 20495053
# NaN after fill: 0
# Fold 4, clipped_laplace, ε=0.1: RMSE=1.2728, NDCG@10=0.9303
# Fold 4, bounded_laplace, ε=0.1: RMSE=1.1246, NDCG@10=0.9288
# Fold 4, gaussian, ε=0.1: RMSE=1.2845, NDCG@10=0.9298
# Fold 4, piecewise, ε=0.1: RMSE=1.1206, NDCG@10=0.9365
# Fold 4, clipped_laplace, ε=0.5: RMSE=1.2255, NDCG@10=0.9322
# Fold 4, bounded_laplace, ε=0.5: RMSE=1.1242, NDCG@10=0.9296
# Fold 4, gaussian, ε=0.5: RMSE=1.2718, NDCG@10=0.9319
# Fold 4, piecewise, ε=0.5: RMSE=1.1202, NDCG@10=0.9366
# Fold 4, clipped_laplace, ε=1.0: RMSE=1.1907, NDCG@10=0.9301
# Fold 4, bounded_laplace, ε=1.0: RMSE=1.1209, NDCG@10=0.9319
# Fold 4, gaussian, ε=1.0: RMSE=1.2613, NDCG@10=0.9315
# Fold 4, piecewise, ε=1.0: RMSE=1.1134, NDCG@10=0.9411
# Fold 4, clipped_laplace, ε=2.0: RMSE=1.1498, NDCG@10=0.9324
# Fold 4, bounded_laplace, ε=2.0: RMSE=1.1189, NDCG@10=0.9347
# Fold 4, gaussian, ε=2.0: RMSE=1.2413, NDCG@10=0.9317
# Fold 4, piecewise, ε=2.0: RMSE=1.1091, NDCG@10=0.9433
# Fold 4, clipped_laplace, ε=5.0: RMSE=1.1213, NDCG@10=0.9328
# Fold 4, bounded_laplace, ε=5.0: RMSE=1.1123, NDCG@10=0.9420
# Fold 4, gaussian, ε=5.0: RMSE=1.1917, NDCG@10=0.9303
# Fold 4, piecewise, ε=5.0: RMSE=1.1025, NDCG@10=0.9505
# Fold 4, clipped_laplace, ε=10.0: RMSE=1.1150, NDCG@10=0.9353
# Fold 4, bounded_laplace, ε=10.0: RMSE=1.1056, NDCG@10=0.9481
# Fold 4, gaussian, ε=10.0: RMSE=1.1426, NDCG@10=0.9327
# Fold 4, piecewise, ε=10.0: RMSE=1.1011, NDCG@10=0.9520
# Fold 5/10
# Train size: 180038, Test size: 20004
# Train matrix shape: (6037, 3428)
# Mean rating: 3.5831, NaN count: 20514798
# NaN after fill: 0
# Fold 5, clipped_laplace, ε=0.1: RMSE=1.2760, NDCG@10=0.9299
# Fold 5, bounded_laplace, ε=0.1: RMSE=1.1248, NDCG@10=0.9289
# Fold 5, gaussian, ε=0.1: RMSE=1.2837, NDCG@10=0.9303
# Fold 5, piecewise, ε=0.1: RMSE=1.1197, NDCG@10=0.9379
# Fold 5, clipped_laplace, ε=0.5: RMSE=1.2266, NDCG@10=0.9313
# Fold 5, bounded_laplace, ε=0.5: RMSE=1.1234, NDCG@10=0.9299
# Fold 5, gaussian, ε=0.5: RMSE=1.2742, NDCG@10=0.9288
# Fold 5, piecewise, ε=0.5: RMSE=1.1184, NDCG@10=0.9373
# Fold 5, clipped_laplace, ε=1.0: RMSE=1.1907, NDCG@10=0.9321
# Fold 5, bounded_laplace, ε=1.0: RMSE=1.1210, NDCG@10=0.9327
# Fold 5, gaussian, ε=1.0: RMSE=1.2609, NDCG@10=0.9313
# Fold 5, piecewise, ε=1.0: RMSE=1.1154, NDCG@10=0.9402
# Fold 5, clipped_laplace, ε=2.0: RMSE=1.1480, NDCG@10=0.9323
# Fold 5, bounded_laplace, ε=2.0: RMSE=1.1182, NDCG@10=0.9353
# Fold 5, gaussian, ε=2.0: RMSE=1.2409, NDCG@10=0.9310
# Fold 5, piecewise, ε=2.0: RMSE=1.1085, NDCG@10=0.9450
# Fold 5, clipped_laplace, ε=5.0: RMSE=1.1198, NDCG@10=0.9346
# Fold 5, bounded_laplace, ε=5.0: RMSE=1.1121, NDCG@10=0.9413
# Fold 5, gaussian, ε=5.0: RMSE=1.1883, NDCG@10=0.9307
# Fold 5, piecewise, ε=5.0: RMSE=1.1035, NDCG@10=0.9493
# Fold 5, clipped_laplace, ε=10.0: RMSE=1.1153, NDCG@10=0.9342
# Fold 5, bounded_laplace, ε=10.0: RMSE=1.1067, NDCG@10=0.9475
# Fold 5, gaussian, ε=10.0: RMSE=1.1423, NDCG@10=0.9314
# Fold 5, piecewise, ε=10.0: RMSE=1.1019, NDCG@10=0.9515
# Fold 6/10
# Train size: 180038, Test size: 20004
# Train matrix shape: (6037, 3427)
# Mean rating: 3.5832, NaN count: 20508761
# NaN after fill: 0
# Fold 6, clipped_laplace, ε=0.1: RMSE=1.2714, NDCG@10=0.9307
# Fold 6, bounded_laplace, ε=0.1: RMSE=1.1267, NDCG@10=0.9288
# Fold 6, gaussian, ε=0.1: RMSE=1.2866, NDCG@10=0.9292
# Fold 6, piecewise, ε=0.1: RMSE=1.1227, NDCG@10=0.9362
# Fold 6, clipped_laplace, ε=0.5: RMSE=1.2273, NDCG@10=0.9318
# Fold 6, bounded_laplace, ε=0.5: RMSE=1.1240, NDCG@10=0.9305
# Fold 6, gaussian, ε=0.5: RMSE=1.2731, NDCG@10=0.9300
# Fold 6, piecewise, ε=0.5: RMSE=1.1208, NDCG@10=0.9374
# Fold 6, clipped_laplace, ε=1.0: RMSE=1.1932, NDCG@10=0.9303
# Fold 6, bounded_laplace, ε=1.0: RMSE=1.1236, NDCG@10=0.9306
# Fold 6, gaussian, ε=1.0: RMSE=1.2646, NDCG@10=0.9307
# Fold 6, piecewise, ε=1.0: RMSE=1.1153, NDCG@10=0.9399
# Fold 6, clipped_laplace, ε=2.0: RMSE=1.1516, NDCG@10=0.9323
# Fold 6, bounded_laplace, ε=2.0: RMSE=1.1207, NDCG@10=0.9335
# Fold 6, gaussian, ε=2.0: RMSE=1.2427, NDCG@10=0.9298
# Fold 6, piecewise, ε=2.0: RMSE=1.1107, NDCG@10=0.9449
# Fold 6, clipped_laplace, ε=5.0: RMSE=1.1213, NDCG@10=0.9346
# Fold 6, bounded_laplace, ε=5.0: RMSE=1.1141, NDCG@10=0.9416
# Fold 6, gaussian, ε=5.0: RMSE=1.1917, NDCG@10=0.9323
# Fold 6, piecewise, ε=5.0: RMSE=1.1049, NDCG@10=0.9502
# Fold 6, clipped_laplace, ε=10.0: RMSE=1.1166, NDCG@10=0.9361
# Fold 6, bounded_laplace, ε=10.0: RMSE=1.1080, NDCG@10=0.9482
# Fold 6, gaussian, ε=10.0: RMSE=1.1448, NDCG@10=0.9308
# Fold 6, piecewise, ε=10.0: RMSE=1.1037, NDCG@10=0.9513
# Fold 7/10
# Train size: 180038, Test size: 20004
# Train matrix shape: (6036, 3428)
# Mean rating: 3.5813, NaN count: 20511370
# NaN after fill: 0
# Fold 7, clipped_laplace, ε=0.1: RMSE=1.2744, NDCG@10=0.9314
# Fold 7, bounded_laplace, ε=0.1: RMSE=1.1219, NDCG@10=0.9298
# Fold 7, gaussian, ε=0.1: RMSE=1.2824, NDCG@10=0.9327
# Fold 7, piecewise, ε=0.1: RMSE=1.1180, NDCG@10=0.9357
# Fold 7, clipped_laplace, ε=0.5: RMSE=1.2313, NDCG@10=0.9315
# Fold 7, bounded_laplace, ε=0.5: RMSE=1.1197, NDCG@10=0.9318
# Fold 7, gaussian, ε=0.5: RMSE=1.2768, NDCG@10=0.9313
# Fold 7, piecewise, ε=0.5: RMSE=1.1137, NDCG@10=0.9379
# Fold 7, clipped_laplace, ε=1.0: RMSE=1.1931, NDCG@10=0.9311
# Fold 7, bounded_laplace, ε=1.0: RMSE=1.1180, NDCG@10=0.9316
# Fold 7, gaussian, ε=1.0: RMSE=1.2637, NDCG@10=0.9319
# Fold 7, piecewise, ε=1.0: RMSE=1.1099, NDCG@10=0.9415
# Fold 7, clipped_laplace, ε=2.0: RMSE=1.1493, NDCG@10=0.9320
# Fold 7, bounded_laplace, ε=2.0: RMSE=1.1139, NDCG@10=0.9357
# Fold 7, gaussian, ε=2.0: RMSE=1.2455, NDCG@10=0.9306
# Fold 7, piecewise, ε=2.0: RMSE=1.1041, NDCG@10=0.9447
# Fold 7, clipped_laplace, ε=5.0: RMSE=1.1181, NDCG@10=0.9338
# Fold 7, bounded_laplace, ε=5.0: RMSE=1.1081, NDCG@10=0.9407
# Fold 7, gaussian, ε=5.0: RMSE=1.1924, NDCG@10=0.9303
# Fold 7, piecewise, ε=5.0: RMSE=1.0986, NDCG@10=0.9502
# Fold 7, clipped_laplace, ε=10.0: RMSE=1.1105, NDCG@10=0.9370
# Fold 7, bounded_laplace, ε=10.0: RMSE=1.1018, NDCG@10=0.9483
# Fold 7, gaussian, ε=10.0: RMSE=1.1409, NDCG@10=0.9337
# Fold 7, piecewise, ε=10.0: RMSE=1.0980, NDCG@10=0.9508
# Fold 8/10
# Train size: 180038, Test size: 20004
# Train matrix shape: (6032, 3431)
# Mean rating: 3.5816, NaN count: 20515754
# NaN after fill: 0
# Fold 8, clipped_laplace, ε=0.1: RMSE=1.2719, NDCG@10=0.9327
# Fold 8, bounded_laplace, ε=0.1: RMSE=1.1188, NDCG@10=0.9306
# Fold 8, gaussian, ε=0.1: RMSE=1.2859, NDCG@10=0.9318
# Fold 8, piecewise, ε=0.1: RMSE=1.1141, NDCG@10=0.9376
# Fold 8, clipped_laplace, ε=0.5: RMSE=1.2277, NDCG@10=0.9322
# Fold 8, bounded_laplace, ε=0.5: RMSE=1.1175, NDCG@10=0.9315
# Fold 8, gaussian, ε=0.5: RMSE=1.2748, NDCG@10=0.9332
# Fold 8, piecewise, ε=0.5: RMSE=1.1119, NDCG@10=0.9386
# Fold 8, clipped_laplace, ε=1.0: RMSE=1.1857, NDCG@10=0.9330
# Fold 8, bounded_laplace, ε=1.0: RMSE=1.1152, NDCG@10=0.9344
# Fold 8, gaussian, ε=1.0: RMSE=1.2629, NDCG@10=0.9330
# Fold 8, piecewise, ε=1.0: RMSE=1.1088, NDCG@10=0.9403
# Fold 8, clipped_laplace, ε=2.0: RMSE=1.1491, NDCG@10=0.9322
# Fold 8, bounded_laplace, ε=2.0: RMSE=1.1125, NDCG@10=0.9364
# Fold 8, gaussian, ε=2.0: RMSE=1.2438, NDCG@10=0.9307
# Fold 8, piecewise, ε=2.0: RMSE=1.1027, NDCG@10=0.9463
# Fold 8, clipped_laplace, ε=5.0: RMSE=1.1160, NDCG@10=0.9333
# Fold 8, bounded_laplace, ε=5.0: RMSE=1.1050, NDCG@10=0.9441
# Fold 8, gaussian, ε=5.0: RMSE=1.1876, NDCG@10=0.9325
# Fold 8, piecewise, ε=5.0: RMSE=1.0965, NDCG@10=0.9517
# Fold 8, clipped_laplace, ε=10.0: RMSE=1.1069, NDCG@10=0.9393
# Fold 8, bounded_laplace, ε=10.0: RMSE=1.1001, NDCG@10=0.9501
# Fold 8, gaussian, ε=10.0: RMSE=1.1379, NDCG@10=0.9345
# Fold 8, piecewise, ε=10.0: RMSE=1.0952, NDCG@10=0.9537
# Fold 9/10
# Train size: 180038, Test size: 20004
# Train matrix shape: (6037, 3427)
# Mean rating: 3.5824, NaN count: 20508761
# NaN after fill: 0
# Fold 9, clipped_laplace, ε=0.1: RMSE=1.2735, NDCG@10=0.9305
# Fold 9, bounded_laplace, ε=0.1: RMSE=1.1224, NDCG@10=0.9292
# Fold 9, gaussian, ε=0.1: RMSE=1.2863, NDCG@10=0.9304
# Fold 9, piecewise, ε=0.1: RMSE=1.1196, NDCG@10=0.9370
# Fold 9, clipped_laplace, ε=0.5: RMSE=1.2268, NDCG@10=0.9315
# Fold 9, bounded_laplace, ε=0.5: RMSE=1.1222, NDCG@10=0.9291
# Fold 9, gaussian, ε=0.5: RMSE=1.2747, NDCG@10=0.9320
# Fold 9, piecewise, ε=0.5: RMSE=1.1169, NDCG@10=0.9376
# Fold 9, clipped_laplace, ε=1.0: RMSE=1.1913, NDCG@10=0.9310
# Fold 9, bounded_laplace, ε=1.0: RMSE=1.1192, NDCG@10=0.9330
# Fold 9, gaussian, ε=1.0: RMSE=1.2643, NDCG@10=0.9297
# Fold 9, piecewise, ε=1.0: RMSE=1.1115, NDCG@10=0.9413
# Fold 9, clipped_laplace, ε=2.0: RMSE=1.1471, NDCG@10=0.9332
# Fold 9, bounded_laplace, ε=2.0: RMSE=1.1164, NDCG@10=0.9352
# Fold 9, gaussian, ε=2.0: RMSE=1.2442, NDCG@10=0.9312
# Fold 9, piecewise, ε=2.0: RMSE=1.1084, NDCG@10=0.9441
# Fold 9, clipped_laplace, ε=5.0: RMSE=1.1202, NDCG@10=0.9340
# Fold 9, bounded_laplace, ε=5.0: RMSE=1.1103, NDCG@10=0.9445
# Fold 9, gaussian, ε=5.0: RMSE=1.1901, NDCG@10=0.9330
# Fold 9, piecewise, ε=5.0: RMSE=1.1013, NDCG@10=0.9497
# Fold 9, clipped_laplace, ε=10.0: RMSE=1.1129, NDCG@10=0.9369
# Fold 9, bounded_laplace, ε=10.0: RMSE=1.1056, NDCG@10=0.9477
# Fold 9, gaussian, ε=10.0: RMSE=1.1406, NDCG@10=0.9327
# Fold 9, piecewise, ε=10.0: RMSE=1.1001, NDCG@10=0.9521
# Fold 10/10
# Train size: 180038, Test size: 20004
# Train matrix shape: (6034, 3417)
# Mean rating: 3.5831, NaN count: 20438140
# NaN after fill: 0
# Fold 10, clipped_laplace, ε=0.1: RMSE=1.2780, NDCG@10=0.9298
# Fold 10, bounded_laplace, ε=0.1: RMSE=1.1329, NDCG@10=0.9278
# Fold 10, gaussian, ε=0.1: RMSE=1.2860, NDCG@10=0.9304
# Fold 10, piecewise, ε=0.1: RMSE=1.1298, NDCG@10=0.9359
# Fold 10, clipped_laplace, ε=0.5: RMSE=1.2339, NDCG@10=0.9306
# Fold 10, bounded_laplace, ε=0.5: RMSE=1.1304, NDCG@10=0.9290
# Fold 10, gaussian, ε=0.5: RMSE=1.2804, NDCG@10=0.9309
# Fold 10, piecewise, ε=0.5: RMSE=1.1254, NDCG@10=0.9375
# Fold 10, clipped_laplace, ε=1.0: RMSE=1.1970, NDCG@10=0.9308
# Fold 10, bounded_laplace, ε=1.0: RMSE=1.1296, NDCG@10=0.9307
# Fold 10, gaussian, ε=1.0: RMSE=1.2726, NDCG@10=0.9291
# Fold 10, piecewise, ε=1.0: RMSE=1.1226, NDCG@10=0.9394
# Fold 10, clipped_laplace, ε=2.0: RMSE=1.1601, NDCG@10=0.9313
# Fold 10, bounded_laplace, ε=2.0: RMSE=1.1261, NDCG@10=0.9343
# Fold 10, gaussian, ε=2.0: RMSE=1.2466, NDCG@10=0.9310
# Fold 10, piecewise, ε=2.0: RMSE=1.1177, NDCG@10=0.9434
# Fold 10, clipped_laplace, ε=5.0: RMSE=1.1284, NDCG@10=0.9344
# Fold 10, bounded_laplace, ε=5.0: RMSE=1.1195, NDCG@10=0.9420
# Fold 10, gaussian, ε=5.0: RMSE=1.1951, NDCG@10=0.9327
# Fold 10, piecewise, ε=5.0: RMSE=1.1111, NDCG@10=0.9497
# Fold 10, clipped_laplace, ε=10.0: RMSE=1.1228, NDCG@10=0.9348
# Fold 10, bounded_laplace, ε=10.0: RMSE=1.1148, NDCG@10=0.9480
# Fold 10, gaussian, ε=10.0: RMSE=1.1495, NDCG@10=0.9322
# Fold 10, piecewise, ε=10.0: RMSE=1.1097, NDCG@10=0.9519
#     epsilon        mechanism  rmse_mean  rmse_std  ndcg_mean  ndcg_std
# 0       0.1  bounded_laplace   1.123599  0.004322   0.929124  0.000778
# 1       0.1  clipped_laplace   1.273752  0.002599   0.930642  0.000986
# 2       0.1         gaussian   1.284571  0.001977   0.930919  0.001057
# 3       0.1        piecewise   1.119835  0.004508   0.936447  0.000996
# 4       0.5  bounded_laplace   1.122056  0.004191   0.930028  0.000977
# 5       0.5  clipped_laplace   1.227787  0.003269   0.931493  0.000639
# 6       0.5         gaussian   1.274913  0.002901   0.931318  0.001253
# 7       0.5        piecewise   1.117302  0.004454   0.937649  0.000610
# 8       1.0  bounded_laplace   1.120002  0.004498   0.932193  0.001102
# 9       1.0  clipped_laplace   1.191121  0.003130   0.931313  0.000922
# 10      1.0         gaussian   1.263522  0.004135   0.931116  0.001140
# 11      1.0        piecewise   1.113088  0.004344   0.940407  0.000866
# 12      2.0  bounded_laplace   1.117208  0.004473   0.935031  0.000790
# 13      2.0  clipped_laplace   1.150199  0.004249   0.932246  0.000537
# 14      2.0         gaussian   1.243337  0.002566   0.930675  0.000674
# 15      2.0        piecewise   1.107849  0.004666   0.944580  0.000892
# 16      5.0  bounded_laplace   1.110786  0.004453   0.942102  0.001294
# 17      5.0  clipped_laplace   1.119727  0.004116   0.933991  0.000603
# 18      5.0         gaussian   1.190319  0.002639   0.931559  0.001077
# 19      5.0        piecewise   1.101712  0.004534   0.950128  0.000689
# 20     10.0  bounded_laplace   1.105049  0.004636   0.948276  0.000692
# 21     10.0  clipped_laplace   1.113476  0.004617   0.936320  0.001493
# 22     10.0         gaussian   1.141992  0.003827   0.932554  0.001108
# 23     10.0        piecewise   1.100558  0.004379   0.951921  0.000748

# %%
results_df.to_excel('ldp_results_20pct_1m.xlsx', index=False)
summary.to_excel('ldp_summary_20pct_1m.xlsx', index=False)

# %%
results_df.to_excel('ldp_results_50pct_1m.xlsx', index=False)
summary.to_excel('ldp_summary_50pct_1m.xlsx', index=False)

# %%
# save full results
results_df.to_excel('ldp_results_natural.xlsx', index=False)

# save summary with mean and std
summary.to_excel('ldp_summary_natural.xlsx', index=False)
